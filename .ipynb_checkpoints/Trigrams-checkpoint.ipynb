# %% [markdown]
# ### Pull debate data from The American Presidency Project
# http://www.presidency.ucsb.edu/index.php

# %% [markdown]
# ####To Dos:
# troubleshoot function for websites with no <b/> or <i/> tags
# make code prettier

# %%
from nltk.collocations import * #Bad form
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import nltk
import json
from pprint import pprint
LOCAL_DATA_PATH = '/Users/willsankey/political_history/data'

# %%
with open(LOCAL_DATA_PATH + "/['63163'].json") as data_file:    
    data = json.load(data_file)
    
#Prints entire debate
#pprint(data)
#print data.keys()
#Print specific paragrah
#data['16']
#Print specific text from paragraph
print data['16']['speaker']
print data['16']['text']
# Out:
# Senator Kerry.
# Yes. When the President had an opportunity to capture or kill Usama bin Laden, he took his focus off of him, outsourced the job to Afghan warlords, and Usama bin Laden escaped. Six months after he said, "Usama bin Laden must be caught, dead or alive," this President was asked, "Where is Usama bin Laden?" He said, "I don't know. I don't really think about him very much. I'm not that concerned." We need a President who stays deadly focused on the real war on terror.

# %%
one_paragraph = data['16']['text']

# %%
tokens = RegexpTokenizer(r'\w+')
token = tokens.tokenize(one_paragraph)
print token
datum = ' '.join(token)
datum = tweet.lower()

# print type(one_paragraph)
#print datum
# print type(datum)
# datum_list = [word for word in datum]
# datum_list
# Out:
# yes when the president had an opportunity to capture or kill usama bin laden he took his focus off of him outsourced the job to afghan warlords and usama bin laden escaped six months after he said usama bin laden must be caught dead or alive this president was asked where is usama bin laden he said i don t know i don t really think about him very much i m not that concerned we need a president who stays deadly focused on the real war on terror

# %%
#Remove stop words
stops = set(stopwords.words('english'))
filtered_words = [word for word in datum if word not in stops]
filtered_words
# Out:
# [u'e',
#  u' ',
#  u'w',
#  u'h',
#  u'e',
#  u'n',
#  u' ',
#  u'h',
#  u'e',
#  u' ',
#  u'p',
#  u'r',
#  u'e',
#  u'e',
#  u'n',
#  u' ',
#  u'h',
#  u' ',
#  u'n',
#  u' ',
#  u'p',
#  u'p',
#  u'r',
#  u'u',
#  u'n',
#  u' ',
#  u' ',
#  u'c',
#  u'p',
#  u'u',
#  u'r',
#  u'e',
#  u' ',
#  u'r',
#  u' ',
#  u'k',
#  u'l',
#  u'l',
#  u' ',
#  u'u',
#  u' ',
#  u'b',
#  u'n',
#  u' ',
#  u'l',
#  u'e',
#  u'n',
#  u' ',
#  u'h',
#  u'e',
#  u' ',
#  u'k',
#  u' ',
#  u'h',
#  u' ',
#  u'f',
#  u'c',
#  u'u',
#  u' ',
#  u'f',
#  u'f',
#  u' ',
#  u'f',
#  u' ',
#  u'h',
#  u' ',
#  u'u',
#  u'u',
#  u'r',
#  u'c',
#  u'e',
#  u' ',
#  u'h',
#  u'e',
#  u' ',
#  u'j',
#  u'b',
#  u' ',
#  u' ',
#  u'f',
#  u'g',
#  u'h',
#  u'n',
#  u' ',
#  u'w',
#  u'r',
#  u'l',
#  u'r',
#  u' ',
#  u'n',
#  u' ',
#  u'u',
#  u' ',
#  u'b',
#  u'n',
#  u' ',
#  u'l',
#  u'e',
#  u'n',
#  u' ',
#  u'e',
#  u'c',
#  u'p',
#  u'e',
#  u' ',
#  u'x',
#  u' ',
#  u'n',
#  u'h',
#  u' ',
#  u'f',
#  u'e',
#  u'r',
#  u' ',
#  u'h',
#  u'e',
#  u' ',
#  u' ',
#  u'u',
#  u' ',
#  u'b',
#  u'n',
#  u' ',
#  u'l',
#  u'e',
#  u'n',
#  u' ',
#  u'u',
#  u' ',
#  u'b',
#  u'e',
#  u' ',
#  u'c',
#  u'u',
#  u'g',
#  u'h',
#  u' ',
#  u'e',
#  u' ',
#  u'r',
#  u' ',
#  u'l',
#  u'v',
#  u'e',
#  u' ',
#  u'h',
#  u' ',
#  u'p',
#  u'r',
#  u'e',
#  u'e',
#  u'n',
#  u' ',
#  u'w',
#  u' ',
#  u'k',
#  u'e',
#  u' ',
#  u'w',
#  u'h',
#  u'e',
#  u'r',
#  u'e',
#  u' ',
#  u' ',
#  u'u',
#  u' ',
#  u'b',
#  u'n',
#  u' ',
#  u'l',
#  u'e',
#  u'n',
#  u' ',
#  u'h',
#  u'e',
#  u' ',
#  u' ',
#  u' ',
#  u'n',
#  u' ',
#  u' ',
#  u'k',
#  u'n',
#  u'w',
#  u' ',
#  u' ',
#  u'n',
#  u' ',
#  u' ',
#  u'r',
#  u'e',
#  u'l',
#  u'l',
#  u' ',
#  u'h',
#  u'n',
#  u'k',
#  u' ',
#  u'b',
#  u'u',
#  u' ',
#  u'h',
#  u' ',
#  u'v',
#  u'e',
#  u'r',
#  u' ',
#  u'u',
#  u'c',
#  u'h',
#  u' ',
#  u' ',
#  u' ',
#  u'n',
#  u' ',
#  u'h',
#  u' ',
#  u'c',
#  u'n',
#  u'c',
#  u'e',
#  u'r',
#  u'n',
#  u'e',
#  u' ',
#  u'w',
#  u'e',
#  u' ',
#  u'n',
#  u'e',
#  u'e',
#  u' ',
#  u' ',
#  u'p',
#  u'r',
#  u'e',
#  u'e',
#  u'n',
#  u' ',
#  u'w',
#  u'h',
#  u' ',
#  u' ',
#  u'e',
#  u'l',
#  u' ',
#  u'f',
#  u'c',
#  u'u',
#  u'e',
#  u' ',
#  u'n',
#  u' ',
#  u'h',
#  u'e',
#  u' ',
#  u'r',
#  u'e',
#  u'l',
#  u' ',
#  u'w',
#  u'r',
#  u' ',
#  u'n',
#  u' ',
#  u'e',
#  u'r',
#  u'r',
#  u'r']

# %%
bifinder = BigramCollocationFinder.from_words(datum.split(), window_size = 2)
trifinder = TrigramCollocationFinder.from_words(datum.split(), window_size = 3)
finder1 = BigramCollocationFinder.from_words(datum.split(), window_size = 2)

finder1.apply_freq_filter(2)
#for Bigram use this syntax --> bigram_measures = nltk.collocations.BigramAssocMeasures()
#for Trigram use this syntax --> trigram_measures = nltk.collocations.TrigramAssocMeasures()
bigram_measures = nltk.collocations.TrigramAssocMeasures()

# %%
for key, value in trifinder.ngram_fd.items():
  tup = (key, value)
  s = " : ".join(map(str, tup))
  print(key, value)
# Out:
# ((u'of', u'him', u'outsourced'), 1)
# ((u'laden', u'must', u'be'), 1)
# ((u't', u'really', u'think'), 1)
# ((u'know', u'i', u'don'), 1)
# ((u'outsourced', u'the', u'job'), 1)
# ((u'and', u'usama', u'bin'), 1)
# ((u'the', u'real', u'war'), 1)
# ((u'i', u'm', u'not'), 1)
# ((u'i', u'don', u't'), 2)
# ((u'afghan', u'warlords', u'and'), 1)
# ((u'about', u'him', u'very'), 1)
# ((u'he', u'said', u'usama'), 1)
# ((u'that', u'concerned', u'we'), 1)
# ((u'bin', u'laden', u'must'), 1)
# ((u'bin', u'laden', u'he'), 2)
# ((u'took', u'his', u'focus'), 1)
# ((u'to', u'capture', u'or'), 1)
# ((u'really', u'think', u'about'), 1)
# ((u'stays', u'deadly', u'focused'), 1)
# ((u'laden', u'he', u'said'), 1)
# ((u'not', u'that', u'concerned'), 1)
# ((u'don', u't', u'really'), 1)
# ((u'had', u'an', u'opportunity'), 1)
# ((u'focus', u'off', u'of'), 1)
# ((u'usama', u'bin', u'laden'), 4)
# ((u'capture', u'or', u'kill'), 1)
# ((u'focused', u'on', u'the'), 1)
# ((u'he', u'said', u'i'), 1)
# ((u'this', u'president', u'was'), 1)
# ((u'concerned', u'we', u'need'), 1)
# ((u'the', u'job', u'to'), 1)
# ((u't', u'know', u'i'), 1)
# ((u'laden', u'escaped', u'six'), 1)
# ((u'bin', u'laden', u'escaped'), 1)
# ((u'him', u'outsourced', u'the'), 1)
# ((u'said', u'usama', u'bin'), 1)
# ((u'think', u'about', u'him'), 1)
# ((u'him', u'very', u'much'), 1)
# ((u'on', u'the', u'real'), 1)
# ((u'who', u'stays', u'deadly'), 1)
# ((u'to', u'afghan', u'warlords'), 1)
# ((u'the', u'president', u'had'), 1)
# ((u'warlords', u'and', u'usama'), 1)
# ((u'months', u'after', u'he'), 1)
# ((u'kill', u'usama', u'bin'), 1)
# ((u'when', u'the', u'president'), 1)
# ((u'caught', u'dead', u'or'), 1)
# ((u'off', u'of', u'him'), 1)
# ((u'very', u'much', u'i'), 1)
# ((u'after', u'he', u'said'), 1)
# ((u'opportunity', u'to', u'capture'), 1)
# ((u'must', u'be', u'caught'), 1)
# ((u'dead', u'or', u'alive'), 1)
# ((u'where', u'is', u'usama'), 1)
# ((u'real', u'war', u'on'), 1)
# ((u'don', u't', u'know'), 1)
# ((u'laden', u'he', u'took'), 1)
# ((u'president', u'was', u'asked'), 1)
# ((u'be', u'caught', u'dead'), 1)
# ((u'his', u'focus', u'off'), 1)
# ((u'a', u'president', u'who'), 1)
# ((u'much', u'i', u'm'), 1)
# ((u'need', u'a', u'president'), 1)
# ((u'an', u'opportunity', u'to'), 1)
# ((u'said', u'i', u'don'), 1)
# ((u'yes', u'when', u'the'), 1)
# ((u'president', u'had', u'an'), 1)
# ((u'or', u'kill', u'usama'), 1)
# ((u'is', u'usama', u'bin'), 1)
# ((u'president', u'who', u'stays'), 1)
# ((u'he', u'took', u'his'), 1)
# ((u'war', u'on', u'terror'), 1)
# ((u'escaped', u'six', u'months'), 1)
# ((u'alive', u'this', u'president'), 1)
# ((u'deadly', u'focused', u'on'), 1)
# ((u'job', u'to', u'afghan'), 1)
# ((u'was', u'asked', u'where'), 1)
# ((u'six', u'months', u'after'), 1)
# ((u'or', u'alive', u'this'), 1)
# ((u'asked', u'where', u'is'), 1)
# ((u'm', u'not', u'that'), 1)
# ((u'we', u'need', u'a'), 1)
