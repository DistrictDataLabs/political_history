# %%
from nltk.collocations import * #Bad form
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import nltk
import json
import pandas as pd
from pprint import pprint
import re

LOCAL_DATA_PATH = '/Users/willsankey/political_history/data'
DATA_LIST = [
            "['102317'].json",
            "['102344'].json",
            "['119038'].json",
            "['72776'].json",
            "['84482'].json",
            "['102322'].json",
            "['118971'].json",
            "['63163'].json",
            "['78691'].json",
            "['84526'].json",
            "['102343'].json",
            "['119012'].json",
            "['72770'].json",
            "['84382'].json"
            ]

# %%
REPUBLICANS = [
    'PRESIDENT BUSH',
    'MCCAIN',
    'RYAN',
    'PALIN',
    'GOV ROMNEY',
    'PENCE',
    'TRUMP'
    
]

# %%
DEMOCRATS = [
    'SENATOR KERRY',
    'THE PRESIDENT',
    'VICE PRESIDENT JOSEPH BIDEN',
    'OBAMA',
    'BIDEN',
    'KAINE',
    'CLINTON'
]

# %%
## Getting the full dataframe

# %%
other_speakers = []
data_list = []
for debate in DATA_LIST:
    with open(LOCAL_DATA_PATH + "/" + debate) as data_file:    
        data = json.load(data_file)

        for paragraph_number, paragraph in data.iteritems():

            paragraph['speaker'] = re.sub('[!@#$.:]', '', paragraph['speaker']).upper()

            if paragraph['speaker'] in REPUBLICANS:
                paragraph['party'] = 'Republican'
            elif paragraph['speaker'] in DEMOCRATS:
                paragraph['party'] = 'Democrat'
            else:
                other_speakers.append(paragraph['speaker'])
                paragraph['party'] = 'NA'
            
            data_list.append(paragraph)
#Checking that we've captured all presidents in speeches.
#print 'Other speakers that were not classified:', set(other_speakers)

# %%
all_data = pd.DataFrame(data_list)

# %%
df = all_data[all_data['party'] != 'NA']

# %%
df.speaker.unique()
# Out:
# array([u'THE PRESIDENT', u'GOV ROMNEY', u'CLINTON', u'TRUMP', u'MCCAIN',
#        u'OBAMA', u'RYAN', u'BIDEN', u'VICE PRESIDENT JOSEPH BIDEN',
#        u'PENCE', u'KAINE', u'PALIN'], dtype=object)

# %%
df.describe()
# Out:
#                    date     party speaker  text  \
# count              3899      3899    3899  3899
# unique               11         2      12  3844
# top     October 4, 2016  Democrat   OBAMA     [
# freq                541      1968     587    14
#
#                                                     title
# count                                                3899
# unique                                                 10
# top     Presidential Candidates Debates: Presidential ...
# freq                                                  809

# %%
df
# Out:
#                  date       party        speaker  \
# 0     October 3, 2012    Democrat  THE PRESIDENT
# 2     October 3, 2012  Republican     GOV ROMNEY
# 3     October 3, 2012  Republican     GOV ROMNEY
# 4     October 3, 2012    Democrat  THE PRESIDENT
# 5     October 3, 2012    Democrat  THE PRESIDENT
# 6     October 3, 2012    Democrat  THE PRESIDENT
# 7     October 3, 2012    Democrat  THE PRESIDENT
# 8     October 3, 2012  Republican     GOV ROMNEY
# 9     October 3, 2012  Republican     GOV ROMNEY
